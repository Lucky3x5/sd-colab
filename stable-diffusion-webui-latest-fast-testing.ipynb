# %%
# %cd /content
# !git clone https://github.com/Lucky3x5/sd-colab.git
# %cd /content/sd-colab
# !git checkout testing
# %env SD_MODELS=https://huggingface.co/nolanaatama/chomni/resolve/main/chomni.safetensors https://huggingface.co/nolanaatama/urpm13/resolve/main/urpm13.ckpt
# !bash /content/sd-colab/install-stable-diffusion-webui-fast.sh
# %cd /content/stable-diffusion-webui
# %env LD_PRELOAD=libtcmalloc_minimal.so.4
# !COMMANDLINE_ARGS="--share --enable-insecure-extension-access --remotemoe" REQS_FILE="requirements.txt" python launch.py
